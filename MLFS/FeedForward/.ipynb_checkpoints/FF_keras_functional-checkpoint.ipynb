# %% [markdown]
# # Feed-forward Neural Networks with Sequential and Functional Keras

# %% [markdown]
# ## Imports

# %%
import tensorflow.keras as tk
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
(X_train_full, y_train_full), (x_test, y_test) = tk.datasets.mnist.load_data()
X_test, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_test, y_train = y_train_full[:5000], y_train_full[5000:]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (55000, 28, 28) (55000,)
# (5000, 28, 28) (5000,)

# %% [markdown]
# ## Sequential model

# %%
model = tkm.Sequential()

model.add(tk.layers.Flatten(input_shape=[28, 28]))
model.add(tk.layers.Dense(256, activation="relu"))
model.add(tk.layers.Dense(128, activation="relu"))
model.add(tk.layers.Dense(10, activation="softmax"))

# %%
model.summary()
tk.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_18 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_47 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_48 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
inp = tk.layers.Flatten(input_shape=[28, 28])
hid1 = tk.layers.Dense(256, activation="relu")
hid2 = tk.layers.Dense(128, activation="relu")
out = tk.layers.Dense(10, activation="softmax")

model = tkm.Sequential([inp, hid1, hid2, out])

# %%
model.summary()
tk.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_19 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_49 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_50 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_51 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
res = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6447 - accuracy: 0.8287 - val_loss: 0.3214 - val_accuracy: 0.9122
# Epoch 2/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2975 - accuracy: 0.9150 - val_loss: 0.2500 - val_accuracy: 0.9278
# Epoch 3/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2437 - accuracy: 0.9301 - val_loss: 0.2127 - val_accuracy: 0.9388
# Epoch 4/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.2081 - accuracy: 0.9402 - val_loss: 0.1861 - val_accuracy: 0.9496
# Epoch 5/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1820 - accuracy: 0.9475 - val_loss: 0.1673 - val_accuracy: 0.9546
# Epoch 6/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1611 - accuracy: 0.9537 - val_loss: 0.1521 - val_accuracy: 0.9592
# Epoch 7/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.1443 - accuracy: 0.9580 - val_loss: 0.1379 - val_accuracy: 0.9638
# Epoch 8/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1303 - accuracy: 0.9627 - val_loss: 0.1290 - val_accuracy: 0.9662
# Epoch 9/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1189 - accuracy: 0.9664 - val_loss: 0.1213 - val_accuracy: 0.9698
# Epoch 10/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1085 - accuracy: 0.9696 - val_loss: 0.1132 - val_accuracy: 0.9712
# Epoch 11/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0996 - accuracy: 0.9721 - val_loss: 0.1072 - val_accuracy: 0.9718
# Epoch 12/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0919 - accuracy: 0.9743 - val_loss: 0.1089 - val_accuracy: 0.9710
# Epoch 13/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0852 - accuracy: 0.9765 - val_loss: 0.0989 - val_accuracy: 0.9730
# Epoch 14/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0791 - accuracy: 0.9786 - val_loss: 0.0945 - val_accuracy: 0.9734
# Epoch 15/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0738 - accuracy: 0.9797 - val_loss: 0.0951 - val_accuracy: 0.9716
# Epoch 16/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0689 - accuracy: 0.9813 - val_loss: 0.0881 - val_accuracy: 0.9756
# Epoch 17/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0642 - accuracy: 0.9828 - val_loss: 0.0875 - val_accuracy: 0.9756
# Epoch 18/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0604 - accuracy: 0.9836 - val_loss: 0.0864 - val_accuracy: 0.9754
# Epoch 19/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0565 - accuracy: 0.9849 - val_loss: 0.0834 - val_accuracy: 0.9772
# Epoch 20/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.0533 - accuracy: 0.9861 - val_loss: 0.0793 - val_accuracy: 0.9778

# %%
pd.DataFrame(res.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) 
plt.show()

# %% [markdown]
# ## Functional model

# %%
inp = tk.layers.Input(shape=[28, 28])
flat1 = tk.layers.Flatten(input_shape=[28, 28])(inp)
hid1 = tk.layers.Dense(2**14, activation="relu")(flat1)
hid2 = tk.layers.Dense(512, activation='relu')(hid1)
hid3 = tk.layers.Dense(28*28, activation='relu')(hid2)
resh = tk.layers.Reshape((28, 28))(hid3)
conc = tk.layers.Concatenate()([inp, resh])
flat2 = tk.layers.Flatten(input_shape=[28, 28])(conc)
out  = tk.layers.Dense(10, activation='softmax')(flat2)

model = tk.Model(inputs=[inp], outputs=[out] )

# %%
model.summary()
tk.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 28, 28)]     0
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 784)          0           input_5[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 16384)        12861440    flatten_20[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 512)          8389120     dense_52[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 784)          402192      dense_53[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 28, 28)       0           dense_54[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 28, 56)       0           input_5[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 1568)         0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 10)           15690       flatten_21[0][0]
# ==================================================================================================
# Total params: 21,668,442
# Trainable params: 21,668,442
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
res = model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 86s 50ms/step - loss: 0.5869 - accuracy: 0.8566 - val_loss: 0.2984 - val_accuracy: 0.9170
# Epoch 2/10
# 1719/1719 [==============================] - 85s 50ms/step - loss: 0.2686 - accuracy: 0.9239 - val_loss: 0.2163 - val_accuracy: 0.9394
# Epoch 3/10
# 1719/1719 [==============================] - 88s 51ms/step - loss: 0.2061 - accuracy: 0.9410 - val_loss: 0.1701 - val_accuracy: 0.9520
# Epoch 4/10
# 1719/1719 [==============================] - 88s 51ms/step - loss: 0.1651 - accuracy: 0.9526 - val_loss: 0.1443 - val_accuracy: 0.9596
# Epoch 5/10
# 1719/1719 [==============================] - 87s 50ms/step - loss: 0.1356 - accuracy: 0.9617 - val_loss: 0.1274 - val_accuracy: 0.9634
# Epoch 6/10
# 1719/1719 [==============================] - 85s 49ms/step - loss: 0.1123 - accuracy: 0.9685 - val_loss: 0.1097 - val_accuracy: 0.9702
# Epoch 7/10
# 1719/1719 [==============================] - 86s 50ms/step - loss: 0.0950 - accuracy: 0.9730 - val_loss: 0.0965 - val_accuracy: 0.9738
# Epoch 8/10
# 1719/1719 [==============================] - 88s 51ms/step - loss: 0.0808 - accuracy: 0.9776 - val_loss: 0.0878 - val_accuracy: 0.9762
# Epoch 9/10
# 1719/1719 [==============================] - 86s 50ms/step - loss: 0.0689 - accuracy: 0.9811 - val_loss: 0.0826 - val_accuracy: 0.9776
# Epoch 10/10
# 1719/1719 [==============================] - 86s 50ms/step - loss: 0.0591 - accuracy: 0.9836 - val_loss: 0.0777 - val_accuracy: 0.9792

# %%
pd.DataFrame(res.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) 
plt.show()

# %% [markdown]
# ## Credits & Links

# %% [markdown]
# https://medium.com/@hanify/sequential-api-vs-functional-api-model-in-keras-266823d7cd5e
