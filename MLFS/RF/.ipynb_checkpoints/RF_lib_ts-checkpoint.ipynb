# %% [markdown]
# # RF Random Forest
# ### Using libraries : $\textit{sklearn}$

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as st
import sklearn.ensemble as se
from sklearn.feature_selection import RFE

# %% [markdown]
# ## Testing

# %%
# Data
df = pd.read_csv('D:/Data/csv/CarSales.csv', header=0)
vals = np.asarray(df['Sales'])
idx = pd.date_range(pd.to_datetime("2000-01-01"), periods=len(vals)).tolist()
ts = pd.DataFrame(vals)
ts.index = idx
ts.plot()
plt.show()

# Stationarization (seasonality)
diff = ts.diff(12)
diff = diff[12:] # trim empty year
diff.to_csv('seaAdj.csv')
ts = pd.Series.from_csv('seaAdj.csv', header=0)
diff.plot()
plt.show()

# Autocorrelation
st.plot_acf(ts)
plt.show()

# Supervised learning
ts = pd.Series.from_csv('seaAdj.csv', header=0)
df = pd.DataFrame()
for i in range(12,0,-1):
    df['t-'+str(i)] = ts.shift(i)
    df['t'] = ts.values
    print(df.head(13))
df = df[13:]
df.to_csv('lags12.csv', index=False)

# Feature importance
df = pd.read_csv('lags12.csv', header=0)
array = df.values
# split into input and output
X = array[:,0:-1]
y = array[:,-1]
model = se.RandomForestRegressor(n_estimators=500, random_state=1)
model.fit(X, y)
print(model.feature_importances_)
names = df.columns.values[0:-1]
ticks = [i for i in range(len(names))]
plt.bar(ticks, model.feature_importances_)
plt.xticks(ticks, names)
plt.show()

# Feature selection of lag variables
df = pd.read_csv('lags12.csv', header=0)
array = df.values
X = array[:,0:-1]
y = array[:,-1]
rfe = RFE(se.RandomForestRegressor(n_estimators=500, random_state=1), 4)
fit = rfe.fit(X, y)
print('Selected Features:')
names = df.columns.values[0:-1]
for i in range(len(fit.support_)):
	if fit.support_[i]:
		print(names[i])
names = df.columns.values[0:-1]
ticks = [i for i in range(len(names))]
plt.bar(ticks, fit.ranking_)
plt.xticks(ticks, names)
plt.show()
# Out:
# c:\program files\python36\lib\site-packages\pandas\core\series.py:3727: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)
#              t-12       t
# 2000-01-13    NaN   687.0
# 2000-01-14    NaN   646.0
# 2000-01-15    NaN  -189.0
# 2000-01-16    NaN  -611.0
# 2000-01-17    NaN  1339.0
# 2000-01-18    NaN    30.0
# 2000-01-19    NaN  1645.0
# 2000-01-20    NaN  -276.0
# 2000-01-21    NaN   561.0
# 2000-01-22    NaN   470.0
# 2000-01-23    NaN  3395.0
# 2000-01-24    NaN   360.0
# 2000-01-25  687.0  3440.0
#              t-12       t   t-11
# 2000-01-13    NaN   687.0    NaN
# 2000-01-14    NaN   646.0    NaN
# 2000-01-15    NaN  -189.0    NaN
# 2000-01-16    NaN  -611.0    NaN
# 2000-01-17    NaN  1339.0    NaN
# 2000-01-18    NaN    30.0    NaN
# 2000-01-19    NaN  1645.0    NaN
# 2000-01-20    NaN  -276.0    NaN
# 2000-01-21    NaN   561.0    NaN
# 2000-01-22    NaN   470.0    NaN
# 2000-01-23    NaN  3395.0    NaN
# 2000-01-24    NaN   360.0  687.0
# 2000-01-25  687.0  3440.0  646.0
#              t-12       t   t-11   t-10
# 2000-01-13    NaN   687.0    NaN    NaN
# 2000-01-14    NaN   646.0    NaN    NaN
# 2000-01-15    NaN  -189.0    NaN    NaN
# 2000-01-16    NaN  -611.0    NaN    NaN
# 2000-01-17    NaN  1339.0    NaN    NaN
# 2000-01-18    NaN    30.0    NaN    NaN
# 2000-01-19    NaN  1645.0    NaN    NaN
# 2000-01-20    NaN  -276.0    NaN    NaN
# 2000-01-21    NaN   561.0    NaN    NaN
# 2000-01-22    NaN   470.0    NaN    NaN
# 2000-01-23    NaN  3395.0    NaN  687.0
# 2000-01-24    NaN   360.0  687.0  646.0
# 2000-01-25  687.0  3440.0  646.0 -189.0
#              t-12       t   t-11   t-10    t-9
# 2000-01-13    NaN   687.0    NaN    NaN    NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN
# 2000-01-21    NaN   561.0    NaN    NaN    NaN
# 2000-01-22    NaN   470.0    NaN    NaN  687.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0
#              t-12       t   t-11   t-10    t-9     t-8
# 2000-01-13    NaN   687.0    NaN    NaN    NaN     NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN     NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN     NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN     NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN     NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN     NaN
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN     NaN
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN     NaN
# 2000-01-21    NaN   561.0    NaN    NaN    NaN   687.0
# 2000-01-22    NaN   470.0    NaN    NaN  687.0   646.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0  -189.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0  -611.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0  1339.0
#              t-12       t   t-11   t-10    t-9     t-8     t-7
# 2000-01-13    NaN   687.0    NaN    NaN    NaN     NaN     NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN     NaN     NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN     NaN     NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN     NaN     NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN     NaN     NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN     NaN     NaN
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN     NaN     NaN
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN     NaN   687.0
# 2000-01-21    NaN   561.0    NaN    NaN    NaN   687.0   646.0
# 2000-01-22    NaN   470.0    NaN    NaN  687.0   646.0  -189.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0  -189.0  -611.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0  -611.0  1339.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0  1339.0    30.0
#              t-12       t   t-11   t-10    t-9     t-8     t-7     t-6
# 2000-01-13    NaN   687.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN     NaN     NaN   687.0
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN     NaN   687.0   646.0
# 2000-01-21    NaN   561.0    NaN    NaN    NaN   687.0   646.0  -189.0
# 2000-01-22    NaN   470.0    NaN    NaN  687.0   646.0  -189.0  -611.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0  -189.0  -611.0  1339.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0  -611.0  1339.0    30.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0  1339.0    30.0  1645.0
#              t-12       t   t-11   t-10    t-9     t-8     t-7     t-6     t-5
# 2000-01-13    NaN   687.0    NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN     NaN     NaN     NaN   687.0
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN     NaN     NaN   687.0   646.0
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN     NaN   687.0   646.0  -189.0
# 2000-01-21    NaN   561.0    NaN    NaN    NaN   687.0   646.0  -189.0  -611.0
# 2000-01-22    NaN   470.0    NaN    NaN  687.0   646.0  -189.0  -611.0  1339.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0  -189.0  -611.0  1339.0    30.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0  -611.0  1339.0    30.0  1645.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0  1339.0    30.0  1645.0  -276.0
#              t-12       t   t-11   t-10    t-9     t-8     t-7     t-6  \
# 2000-01-13    NaN   687.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN     NaN     NaN   687.0
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN     NaN   687.0   646.0
# 2000-01-21    NaN   561.0    NaN    NaN    NaN   687.0   646.0  -189.0
# 2000-01-22    NaN   470.0    NaN    NaN  687.0   646.0  -189.0  -611.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0  -189.0  -611.0  1339.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0  -611.0  1339.0    30.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0  1339.0    30.0  1645.0
#
#                t-5     t-4
# 2000-01-13     NaN     NaN
# 2000-01-14     NaN     NaN
# 2000-01-15     NaN     NaN
# 2000-01-16     NaN     NaN
# 2000-01-17     NaN   687.0
# 2000-01-18   687.0   646.0
# 2000-01-19   646.0  -189.0
# 2000-01-20  -189.0  -611.0
# 2000-01-21  -611.0  1339.0
# 2000-01-22  1339.0    30.0
# 2000-01-23    30.0  1645.0
# 2000-01-24  1645.0  -276.0
# 2000-01-25  -276.0   561.0
#              t-12       t   t-11   t-10    t-9     t-8     t-7     t-6  \
# 2000-01-13    NaN   687.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN     NaN     NaN   687.0
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN     NaN   687.0   646.0
# 2000-01-21    NaN   561.0    NaN    NaN    NaN   687.0   646.0  -189.0
# 2000-01-22    NaN   470.0    NaN    NaN  687.0   646.0  -189.0  -611.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0  -189.0  -611.0  1339.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0  -611.0  1339.0    30.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0  1339.0    30.0  1645.0
#
#                t-5     t-4     t-3
# 2000-01-13     NaN     NaN     NaN
# 2000-01-14     NaN     NaN     NaN
# 2000-01-15     NaN     NaN     NaN
# 2000-01-16     NaN     NaN   687.0
# 2000-01-17     NaN   687.0   646.0
# 2000-01-18   687.0   646.0  -189.0
# 2000-01-19   646.0  -189.0  -611.0
# 2000-01-20  -189.0  -611.0  1339.0
# 2000-01-21  -611.0  1339.0    30.0
# 2000-01-22  1339.0    30.0  1645.0
# 2000-01-23    30.0  1645.0  -276.0
# 2000-01-24  1645.0  -276.0   561.0
# 2000-01-25  -276.0   561.0   470.0
#              t-12       t   t-11   t-10    t-9     t-8     t-7     t-6  \
# 2000-01-13    NaN   687.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN     NaN     NaN   687.0
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN     NaN   687.0   646.0
# 2000-01-21    NaN   561.0    NaN    NaN    NaN   687.0   646.0  -189.0
# 2000-01-22    NaN   470.0    NaN    NaN  687.0   646.0  -189.0  -611.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0  -189.0  -611.0  1339.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0  -611.0  1339.0    30.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0  1339.0    30.0  1645.0
#
#                t-5     t-4     t-3     t-2
# 2000-01-13     NaN     NaN     NaN     NaN
# 2000-01-14     NaN     NaN     NaN     NaN
# 2000-01-15     NaN     NaN     NaN   687.0
# 2000-01-16     NaN     NaN   687.0   646.0
# 2000-01-17     NaN   687.0   646.0  -189.0
# 2000-01-18   687.0   646.0  -189.0  -611.0
# 2000-01-19   646.0  -189.0  -611.0  1339.0
# 2000-01-20  -189.0  -611.0  1339.0    30.0
# 2000-01-21  -611.0  1339.0    30.0  1645.0
# 2000-01-22  1339.0    30.0  1645.0  -276.0
# 2000-01-23    30.0  1645.0  -276.0   561.0
# 2000-01-24  1645.0  -276.0   561.0   470.0
# 2000-01-25  -276.0   561.0   470.0  3395.0
#              t-12       t   t-11   t-10    t-9     t-8     t-7     t-6  \
# 2000-01-13    NaN   687.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-14    NaN   646.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-15    NaN  -189.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-16    NaN  -611.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-17    NaN  1339.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-18    NaN    30.0    NaN    NaN    NaN     NaN     NaN     NaN
# 2000-01-19    NaN  1645.0    NaN    NaN    NaN     NaN     NaN   687.0
# 2000-01-20    NaN  -276.0    NaN    NaN    NaN     NaN   687.0   646.0
# 2000-01-21    NaN   561.0    NaN    NaN    NaN   687.0   646.0  -189.0
# 2000-01-22    NaN   470.0    NaN    NaN  687.0   646.0  -189.0  -611.0
# 2000-01-23    NaN  3395.0    NaN  687.0  646.0  -189.0  -611.0  1339.0
# 2000-01-24    NaN   360.0  687.0  646.0 -189.0  -611.0  1339.0    30.0
# 2000-01-25  687.0  3440.0  646.0 -189.0 -611.0  1339.0    30.0  1645.0
#
#                t-5     t-4     t-3     t-2     t-1
# 2000-01-13     NaN     NaN     NaN     NaN     NaN
# 2000-01-14     NaN     NaN     NaN     NaN   687.0
# 2000-01-15     NaN     NaN     NaN   687.0   646.0
# 2000-01-16     NaN     NaN   687.0   646.0  -189.0
# 2000-01-17     NaN   687.0   646.0  -189.0  -611.0
# 2000-01-18   687.0   646.0  -189.0  -611.0  1339.0
# 2000-01-19   646.0  -189.0  -611.0  1339.0    30.0
# 2000-01-20  -189.0  -611.0  1339.0    30.0  1645.0
# 2000-01-21  -611.0  1339.0    30.0  1645.0  -276.0
# 2000-01-22  1339.0    30.0  1645.0  -276.0   561.0
# 2000-01-23    30.0  1645.0  -276.0   561.0   470.0
# 2000-01-24  1645.0  -276.0   561.0   470.0  3395.0
# 2000-01-25  -276.0   561.0   470.0  3395.0   360.0
# [0.05576947 0.11611643 0.09068402 0.05570585 0.07793815 0.08377444
#  0.08702181 0.0587311  0.10969621 0.05737765 0.14253953 0.06464534]
# Selected Features:
# t
# t-7
# t-5
# t-3
